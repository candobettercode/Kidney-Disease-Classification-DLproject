# %%
import os
from datetime import datetime

# %%
# configBox
d = {"key":"Val",
     "key1":"val1"   
    }

# %%
d['key']
# Out:
# 'Val'

# %%
d.key
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 d.key
#
# AttributeError: 'dict' object has no attribute 'key'

# %%
from box import ConfigBox

# %%
d2 = ConfigBox({"key":"Val",
     "key1":"val1"   
    })

# %%
d2.key
# Out:
# 'Val'

# %%
 type(d)
# Out:
# dict

# %%
type(d2)
# Out:
# box.config_box.ConfigBox

# %%
# ensure annotation

def get_product(x:int, y:int)->int:
    return x*y

# %%
get_product(x=3,y=5)
# Out:
# 15

# %%
get_product(x='s',y=5)
# Out:
# 'sssss'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_product(x:int, y:int)->int:
    return x*y

# %%
get_product(x=3,y=5)
# Out:
# 15

# %%
get_product(x='s',y=5)
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 get_product(x='s',y=5)
#
# File e:\6_learning\Kidney-Disease-Classification-DLproject\venv\Lib\site-packages\ensure\main.py:845, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     840     if not isinstance(value, templ):
#     841         msg = (
#     842             "Argument {arg} of type {valt} to {f} "
#     843             "does not match annotation type {t}"
#     844         )
# --> 845         raise EnsureError(msg.format(
#     846             arg=arg, f=self.f, t=templ, valt=type(value)
#     847         ))
#     849 return_val = self.f(*args, **kwargs)
#     850 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument x of type <class 'str'> to <function get_product at 0x000002C05FBAC0E0> does not match annotation type <class 'int'>

# %%
## download data from gdrive

# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1rqSXrt3ldiq1SdcaRzQ9a0lanlRRdUlc/view?usp=drive_link"

# %%
file_url = url.split("/")[5]
file_url
# Out:
# '1rqSXrt3ldiq1SdcaRzQ9a0lanlRRdUlc'

# %%
prefix = "https://drive.google.com/uc?id="

# %%
gdown.download(prefix+file_url,"kidney_ct.rar")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1rqSXrt3ldiq1SdcaRzQ9a0lanlRRdUlc
# To: e:\6_learning\Kidney-Disease-Classification-DLproject\research\kidney_ct.rar
# 100%|██████████| 38.9M/38.9M [00:03<00:00, 11.2MB/s]
# 'kidney_ct.rar'
